# %%
#Ejercicio: rea una calculadora que acepte dos números y una operación (suma, resta, multiplicación, división) como entrada y use funciones lambda para realizar la operación deseada.
#pregunta:
def primer_numero(a):
  int(input("Ingresa un número:"))

def segundo_numero(b):
  int(input("Ingresa el segundo número:"))

def operacion(operacion):
  input(Ingresa la operación que desees realizar:)
  y = lambda a, b :
    if operacion == "+":
      print(y(a+b))
    elif operacion == "-":
      print(y(a-b))
    elif operacion == "*":
      print(y(a*b))
    elif operacion == "/":
      print(y(a/b))
# Out:
#   File "<ipython-input-3-76300ebb681f>", line 10
#     input(Ingresa la operación que desees realizar:)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Hecho en clase
lista=list(input("Dame dos números y una operación"))
lista=[float(lista[0])],float(lista[2])
operacion=input("Dame una operación")

def calculadora(lista,operacion):
  res = lambda a,b:
  if operacion == "suma":
    print(res(lista[0], lista[2]))

# %%
#Hecho en clase
lista=list(input("Dame dos números y una operación"))
lista=[float(lista[0])],float(lista[2])
operacion=input("Dame una operación")

def....
  if operacion=="suma":
    suma=lambda a,b : a+b
    res=suma(lista[0],lista[2])
  elif operacion=="resta":
    resta=lambda a,b : a-b
    res=resta(lista[0],lista[2])
  elif operacion=="multiplicacion":
    multiplicacion=lambda a,b : a*b
    res=multiplicacion(lista[0],lista[2])
  elif operacion=="division":
    division=lambda a,b : a/b
    res=division(lista[0],lista[2])
  return print("El resultado es:" res)
